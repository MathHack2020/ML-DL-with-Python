# %% [markdown]
# <div style='color: #216969;
#            background-color: #EAF6F6;
#            font-size: 200%;
#            border-radius:15px;
#            text-align:center;
#            font-weight:600;
#            border-style: solid;
#            border-color: dark green;
#            font-family: "Cambria";'>
# Numerical feature Engineering   ....
# <a class="anchor" id="1"></a>

# %% [markdown]
# ![image.png](attachment:image.png)
# Pearson correlation coefficient

# %% [markdown]
# $ \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^{n} (x_i - \bar{x})^2} \cdot \sqrt{\sum_{i=1}^{n} (y_i - \bar{y})^2}}$
#
# The Pearson correlation coefficient, often denoted as ( r ), measures the strength and direction of the linear relationship between two variables, ( X ) and ( Y ). It ranges from -1 to 1, where 1 indicates a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 indicates no linear relationship.

# %%
#Data Loading 
import pandas as pd
df= pd.read_csv("../data/HousePrice1.csv")

# %% [markdown]
# ![](../imgs/featureEngin.png)

# %% [markdown]
# ![](../../imgs/featureEngin.png)

# %%
df.shape
# Out:
# (1460, 76)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage     float64
#                  ...
# TotalSF           int64
# TotalPorchSF      int64
# TotalBath       float64
# SnMoSold        float64
# CsMoSold        float64
# Length: 76, dtype: object

# %%
# numerical features 
num_features= df.select_dtypes("number")
num_features.dtypes
# Out:
# Unnamed: 0        int64
# Id                int64
# MSSubClass        int64
# LotFrontage     float64
# LotArea           int64
# OverallQual       int64
# OverallCond       int64
# YearBuilt         int64
# YearRemodAdd      int64
# MasVnrArea      float64
# BsmtFinSF1        int64
# BsmtFinSF2        int64
# BsmtUnfSF         int64
# 1stFlrSF          int64
# 2ndFlrSF          int64
# LowQualFinSF      int64
# BedroomAbvGr      int64
# KitchenAbvGr      int64
# TotRmsAbvGrd      int64
# Fireplaces        int64
# GarageYrBlt     float64
# GarageCars        int64
# GarageArea        int64
# WoodDeckSF        int64
# PoolArea          int64
# MiscVal           int64
# YrSold            int64
# SalePrice         int64
# TotalSF           int64
# TotalPorchSF      int64
# TotalBath       float64
# SnMoSold        float64
# CsMoSold        float64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0           0   1          60       RL         65.0     8450   Pave   NaN
# 1           1   2          20       RL         80.0     9600   Pave   NaN
# 2           2   3          60       RL         68.0    11250   Pave   NaN
# 3           3   4          70       RL         60.0     9550   Pave   NaN
# 4           4   5          60       RL         84.0    14260   Pave   NaN
#
#   LotShape LandContour  ... MiscVal YrSold SaleType SaleCondition SalePrice  \
# 0      Reg         Lvl  ...       0   2008       WD        Normal    208500
# 1      Reg         Lvl  ...       0   2007       WD        Normal    181500
# 2      IR1         Lvl  ...       0   2008       WD        Normal    223500
# 3      IR1         Lvl  ...       0   2006       WD       Abnorml    140000
# 4      IR1         Lvl  ...       0   2008       WD        Normal    250000
#
#   TotalSF TotalPorchSF TotalBath      SnMoSold      CsMoSold
# 0    1404           61       3.5  8.660254e-01  5.000000e-01
# 1    1722            0       2.5  5.000000e-01 -8.660254e-01
# 2    1528           42       3.5 -1.000000e+00 -1.836970e-16
# 3    1398          307       2.0  8.660254e-01  5.000000e-01
# 4    1981           84       3.5 -2.449294e-16  1.000000e+00
#
# [5 rows x 76 columns]

# %%
num_features.corr()
# Out:
#               Unnamed: 0        Id  MSSubClass  LotFrontage   LotArea  \
# Unnamed: 0      1.000000  1.000000    0.011156    -0.010601 -0.033226
# Id              1.000000  1.000000    0.011156    -0.010601 -0.033226
# MSSubClass      0.011156  0.011156    1.000000    -0.386347 -0.139781
# LotFrontage    -0.010601 -0.010601   -0.386347     1.000000  0.426095
# LotArea        -0.033226 -0.033226   -0.139781     0.426095  1.000000
# OverallQual    -0.028365 -0.028365    0.032628     0.251646  0.105806
# OverallCond     0.012609  0.012609   -0.059316    -0.059213 -0.005636
# YearBuilt      -0.012713 -0.012713    0.027850     0.123349  0.014228
# YearRemodAdd   -0.021998 -0.021998    0.040581     0.088866  0.013788
# MasVnrArea     -0.050298 -0.050298    0.022936     0.193458  0.104160
# BsmtFinSF1     -0.005024 -0.005024   -0.069836     0.233633  0.214103
# BsmtFinSF2     -0.005968 -0.005968   -0.065649     0.049900  0.111170
# BsmtUnfSF      -0.007940 -0.007940   -0.140759     0.132644 -0.002618
# 1stFlrSF        0.010496  0.010496   -0.251758     0.457181  0.299475
# 2ndFlrSF        0.005590  0.005590    0.307886     0.080177  0.050986
# LowQualFinSF   -0.044230 -0.044230    0.046474     0.038469  0.004779
# BedroomAbvGr    0.037719  0.037719   -0.023438     0.263170  0.119690
# KitchenAbvGr    0.002951  0.002951    0.281721    -0.006069 -0.017784
# TotRmsAbvGrd    0.027239  0.027239    0.040380     0.352096  0.190015
# Fireplaces     -0.019772 -0.019772   -0.045569     0.266639  0.271364
# GarageYrBlt     0.000072  0.000072    0.085072     0.070250 -0.024947
# GarageCars      0.016570  0.016570   -0.040110     0.285691  0.154871
# GarageArea      0.017634  0.017634   -0.098672     0.344997  0.180403
# WoodDeckSF     -0.029643 -0.029643   -0.012579     0.088521  0.171698
# PoolArea        0.057044  0.057044    0.008283     0.206167  0.077672
# MiscVal        -0.006242 -0.006242   -0.007683     0.003368  0.038068
# YrSold          0.000712  0.000712   -0.021407     0.007450 -0.014261
# SalePrice      -0.021917 -0.021917   -0.084284     0.351799  0.263843
# TotalSF        -0.005213 -0.005213   -0.219054     0.425195  0.266552
# TotalPorchSF   -0.010914 -0.010914   -0.036848     0.142318  0.071310
# TotalBath       0.004540  0.004540    0.151048     0.220092  0.204764
# SnMoSold       -0.015982 -0.015982    0.019031    -0.023236 -0.017768
# CsMoSold        0.005031  0.005031   -0.022421     0.041430  0.000082
#
#               OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# Unnamed: 0      -0.028365     0.012609  -0.012713     -0.021998   -0.050298
# Id              -0.028365     0.012609  -0.012713     -0.021998   -0.050298
# MSSubClass       0.032628    -0.059316   0.027850      0.040581    0.022936
# LotFrontage      0.251646    -0.059213   0.123349      0.088866    0.193458
# LotArea          0.105806    -0.005636   0.014228      0.013788    0.104160
# OverallQual      1.000000    -0.091932   0.572323      0.550684    0.411876
# OverallCond     -0.091932     1.000000  -0.375983      0.073741   -0.128101
# YearBuilt        0.572323    -0.375983   1.000000      0.592855    0.315707
# YearRemodAdd     0.550684     0.073741   0.592855      1.000000    0.179618
# MasVnrArea       0.411876    -0.128101   0.315707      0.179618    1.000000
# BsmtFinSF1       0.239666    -0.046231   0.249503      0.128451    0.264736
# BsmtFinSF2      -0.059119     0.040229  -0.049107     -0.067759   -0.072319
# BsmtUnfSF        0.308159    -0.136841   0.149040      0.181133    0.114442
# 1stFlrSF         0.476224    -0.144203   0.281986      0.240379    0.344501
# 2ndFlrSF         0.295493     0.028942   0.010308      0.140024    0.174561
# LowQualFinSF    -0.030429     0.025494  -0.183784     -0.062419   -0.069071
# BedroomAbvGr     0.101676     0.012980  -0.070651     -0.040581    0.102821
# KitchenAbvGr    -0.183882    -0.087001  -0.174800     -0.149598   -0.037610
# TotRmsAbvGrd     0.427452    -0.057583   0.095589      0.191740    0.280682
# Fireplaces       0.396765    -0.023820   0.147716      0.112581    0.249070
# GarageYrBlt      0.547766    -0.324297   0.825667      0.642277    0.252691
# GarageCars       0.600671    -0.185758   0.537850      0.420622    0.364204
# GarageArea       0.562022    -0.151521   0.478954      0.371600    0.373066
# WoodDeckSF       0.238923    -0.003334   0.224880      0.205726    0.159718
# PoolArea         0.065166    -0.001985   0.004950      0.005829    0.011723
# MiscVal         -0.031406     0.068777  -0.034383     -0.010286   -0.029815
# YrSold          -0.027347     0.043950  -0.013618      0.035743   -0.008201
# SalePrice        0.790982    -0.077856   0.522897      0.507101    0.477493
# TotalSF          0.620392    -0.187210   0.477590      0.360877    0.417233
# TotalPorchSF     0.171172     0.056514  -0.124126      0.021951    0.052799
# TotalBath        0.541063    -0.174032   0.524298      0.443719    0.319557
# SnMoSold        -0.052544    -0.010099  -0.002069     -0.022009   -0.013182
# CsMoSold         0.064719    -0.092479   0.045656      0.000321    0.032588
#
#               ...  WoodDeckSF  PoolArea   MiscVal    YrSold  SalePrice  \
# Unnamed: 0    ...   -0.029643  0.057044 -0.006242  0.000712  -0.021917
# Id            ...   -0.029643  0.057044 -0.006242  0.000712  -0.021917
# MSSubClass    ...   -0.012579  0.008283 -0.007683 -0.021407  -0.084284
# LotFrontage   ...    0.088521  0.206167  0.003368  0.007450   0.351799
# LotArea       ...    0.171698  0.077672  0.038068 -0.014261   0.263843
# OverallQual   ...    0.238923  0.065166 -0.031406 -0.027347   0.790982
# OverallCond   ...   -0.003334 -0.001985  0.068777  0.043950  -0.077856
# YearBuilt     ...    0.224880  0.004950 -0.034383 -0.013618   0.522897
# YearRemodAdd  ...    0.205726  0.005829 -0.010286  0.035743   0.507101
# MasVnrArea    ...    0.159718  0.011723 -0.029815 -0.008201   0.477493
# BsmtFinSF1    ...    0.204306  0.140491  0.003571  0.014359   0.386420
# BsmtFinSF2    ...    0.067898  0.041709  0.004940  0.031706  -0.011378
# BsmtUnfSF     ...   -0.005316 -0.035092 -0.023837 -0.041258   0.214479
# 1stFlrSF      ...    0.235459  0.131525 -0.021096 -0.013604   0.605852
# 2ndFlrSF      ...    0.092165  0.081487  0.016197 -0.028700   0.319334
# LowQualFinSF  ...   -0.025444  0.062157 -0.003793 -0.028921  -0.025606
# BedroomAbvGr  ...    0.046854  0.070703  0.007767 -0.036014   0.168213
# KitchenAbvGr  ...   -0.090130 -0.014525  0.062341  0.031687  -0.135907
# TotRmsAbvGrd  ...    0.165984  0.083757  0.024763 -0.034516   0.533723
# Fireplaces    ...    0.200019  0.095074  0.001409 -0.024096   0.466929
# GarageYrBlt   ...    0.224577 -0.014501 -0.032417 -0.001014   0.486362
# GarageCars    ...    0.226342  0.020934 -0.043080 -0.039117   0.640409
# GarageArea    ...    0.224666  0.061047 -0.027400 -0.027378   0.623431
# WoodDeckSF    ...    1.000000  0.073378 -0.009551  0.022270   0.324413
# PoolArea      ...    0.073378  1.000000  0.029669 -0.059689   0.092404
# MiscVal       ...   -0.009551  0.029669  1.000000  0.004906  -0.021190
# YrSold        ...    0.022270 -0.059689  0.004906  1.000000  -0.028923
# SalePrice     ...    0.324413  0.092404 -0.021190 -0.028923   1.000000
# TotalSF       ...    0.261017  0.119082 -0.024330 -0.021638   0.701179
# TotalPorchSF  ...   -0.084709  0.094734  0.015995 -0.031189   0.195739
# TotalBath     ...    0.288200  0.089677 -0.025957  0.020144   0.631731
# SnMoSold      ...   -0.013225 -0.010331  0.003606  0.162773  -0.055101
# CsMoSold      ...    0.043989  0.015235 -0.022597 -0.030989   0.036300
#
#                TotalSF  TotalPorchSF  TotalBath  SnMoSold  CsMoSold
# Unnamed: 0   -0.005213     -0.010914   0.004540 -0.015982  0.005031
# Id           -0.005213     -0.010914   0.004540 -0.015982  0.005031
# MSSubClass   -0.219054     -0.036848   0.151048  0.019031 -0.022421
# LotFrontage   0.425195      0.142318   0.220092 -0.023236  0.041430
# LotArea       0.266552      0.071310   0.204764 -0.017768  0.000082
# OverallQual   0.620392      0.171172   0.541063 -0.052544  0.064719
# OverallCond  -0.187210      0.056514  -0.174032 -0.010099 -0.092479
# YearBuilt     0.477590     -0.124126   0.524298 -0.002069  0.045656
# YearRemodAdd  0.360877      0.021951   0.443719 -0.022009  0.000321
# MasVnrArea    0.417233      0.052799   0.319557 -0.013182  0.032588
# BsmtFinSF1    0.509885      0.051199   0.481609  0.013663  0.071972
# BsmtFinSF2    0.073317      0.061929   0.051709  0.016631 -0.030200
# BsmtUnfSF     0.385737      0.078901  -0.104496 -0.034486  0.024576
# 1stFlrSF      0.808804      0.158072   0.390557 -0.029687  0.078947
# 2ndFlrSF     -0.081847      0.181782   0.375160 -0.054643 -0.030619
# LowQualFinSF -0.050590      0.059994  -0.041203  0.013604  0.011428
# BedroomAbvGr  0.062865      0.099901   0.234885 -0.061921 -0.030000
# KitchenAbvGr -0.076661     -0.056683   0.038331 -0.035697  0.008864
# TotRmsAbvGrd  0.344097      0.179536   0.460273 -0.049754  0.000866
# Fireplaces    0.359746      0.193231   0.331652 -0.020386  0.050006
# GarageYrBlt   0.444955     -0.063799   0.480402  0.010814  0.057552
# GarageCars    0.660863      0.083265   0.483578 -0.037388  0.031577
# GarageArea    0.744444      0.118346   0.451567 -0.035224  0.039260
# WoodDeckSF    0.261017     -0.084709   0.288200 -0.013225  0.043989
# PoolArea      0.119082      0.094734   0.089677 -0.010331  0.015235
# MiscVal      -0.024330      0.015995  -0.025957  0.003606 -0.022597
# YrSold       -0.021638     -0.031189   0.020144  0.162773 -0.030989
# SalePrice     0.701179      0.195739   0.631731 -0.055101  0.036300
# TotalSF       1.000000      0.162909   0.484980 -0.024137  0.082244
# TotalPorchSF  0.162909      1.000000   0.124093 -0.017890  0.031124
# TotalBath     0.484980      0.124093   1.000000 -0.043951  0.037330
# SnMoSold     -0.024137     -0.017890  -0.043951  1.000000 -0.030816
# CsMoSold      0.082244      0.031124   0.037330 -0.030816  1.000000
#
# [33 rows x 33 columns]

# %%
#  Features correration with SalePrice 
import numpy as np
cormat=np.abs(num_features.corr()["SalePrice"]).sort_values(ascending=False)
cormat
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# TotalSF         0.701179
# GarageCars      0.640409
# TotalBath       0.631731
# GarageArea      0.623431
# 1stFlrSF        0.605852
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# LotArea         0.263843
# BsmtUnfSF       0.214479
# TotalPorchSF    0.195739
# BedroomAbvGr    0.168213
# KitchenAbvGr    0.135907
# PoolArea        0.092404
# MSSubClass      0.084284
# OverallCond     0.077856
# SnMoSold        0.055101
# CsMoSold        0.036300
# YrSold          0.028923
# LowQualFinSF    0.025606
# Unnamed: 0      0.021917
# Id              0.021917
# MiscVal         0.021190
# BsmtFinSF2      0.011378
# Name: SalePrice, dtype: float64

# %%
# Display HIghly Correlated Features
cormat[cormat>.6]
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# TotalSF        0.701179
# GarageCars     0.640409
# TotalBath      0.631731
# GarageArea     0.623431
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %%
#7 Highly Correlated Features
cormat.nlargest(7)
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# TotalSF        0.701179
# GarageCars     0.640409
# TotalBath      0.631731
# GarageArea     0.623431
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %%
# 7 Highly Correlated Features
df[["OverallQual", "TotalSF","GarageCars","TotalBath","GarageArea","1stFlrSF","SalePrice"]].corr()
# Out:
#              OverallQual   TotalSF  GarageCars  TotalBath  GarageArea  \
# OverallQual     1.000000  0.620392    0.600671   0.541063    0.562022
# TotalSF         0.620392  1.000000    0.660863   0.484980    0.744444
# GarageCars      0.600671  0.660863    1.000000   0.483578    0.882475
# TotalBath       0.541063  0.484980    0.483578   1.000000    0.451567
# GarageArea      0.562022  0.744444    0.882475   0.451567    1.000000
# 1stFlrSF        0.476224  0.808804    0.439317   0.390557    0.489782
# SalePrice       0.790982  0.701179    0.640409   0.631731    0.623431
#
#              1stFlrSF  SalePrice
# OverallQual  0.476224   0.790982
# TotalSF      0.808804   0.701179
# GarageCars   0.439317   0.640409
# TotalBath    0.390557   0.631731
# GarageArea   0.489782   0.623431
# 1stFlrSF     1.000000   0.605852
# SalePrice    0.605852   1.000000

# %%
# Visualize  7 highest  Correlated features 
cormat_col= cormat.nlargest(7).index
cormat_col
# Out:
# Index(['SalePrice', 'OverallQual', 'TotalSF', 'GarageCars', 'TotalBath',
#        'GarageArea', '1stFlrSF'],
#       dtype='object')

# %%
df[cormat_col].corr()
# Out:
#              SalePrice  OverallQual   TotalSF  GarageCars  TotalBath  \
# SalePrice     1.000000     0.790982  0.701179    0.640409   0.631731
# OverallQual   0.790982     1.000000  0.620392    0.600671   0.541063
# TotalSF       0.701179     0.620392  1.000000    0.660863   0.484980
# GarageCars    0.640409     0.600671  0.660863    1.000000   0.483578
# TotalBath     0.631731     0.541063  0.484980    0.483578   1.000000
# GarageArea    0.623431     0.562022  0.744444    0.882475   0.451567
# 1stFlrSF      0.605852     0.476224  0.808804    0.439317   0.390557
#
#              GarageArea  1stFlrSF
# SalePrice      0.623431  0.605852
# OverallQual    0.562022  0.476224
# TotalSF        0.744444  0.808804
# GarageCars     0.882475  0.439317
# TotalBath      0.451567  0.390557
# GarageArea     1.000000  0.489782
# 1stFlrSF       0.489782  1.000000

# %%
# Heatmap of Highly Correlated Features
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
df_cor=df[cormat_col].corr()

_=sns.heatmap(df_cor, 
              mask=np.triu(df_cor),  
              cbar_kws={"orientation": "horizontal"})

# %%
#  OverallQual   unique values 
df.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
#  pivolt table  for median SalePrice regarding     OverallQual  
median_SalePrice_OvalQ= pd.pivot_table(df, index="OverallQual", values="SalePrice" , aggfunc="median")
median_SalePrice_OvalQ
# Out:
#              SalePrice
# OverallQual
# 1              50150.0
# 2              60000.0
# 3              86250.0
# 4             108000.0
# 5             133000.0
# 6             160000.0
# 7             200141.0
# 8             269750.0
# 9             345000.0
# 10            432390.0
