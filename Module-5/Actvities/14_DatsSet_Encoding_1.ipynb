# %% [markdown]
# | |<font size="5">Data Encoding ترميز البيانات </font>|
# |-:|-:|
# |<img src="https://www.genome.gov/sites/default/files/media/images/2019-03/2.4.8.6.6.4_ENCODE.jpg" width=400></img>||
# ||<font size="4"> تحميل البيانات </font>|
# ||<font size="4"> تنويع استراتيجيات ترميز البيانات</font>|

# %%
# معالجة البيانات الغير رقمية 
# السؤال ما العمل مع هذه البيانات

# %%
#تحميل البيانات 
import pandas as pd
# read_csv(..., nrows=999999)
df= pd.read_csv("../data/HousePrice3.csv", index_col=0)

# %%
df.head(10)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
# 5          50       RL         85.0    14115   Pave   NaN      IR1
# 6          20       RL         75.0    10084   Pave   NaN      Reg
# 7          60       RL          NaN    10382   Pave   NaN      IR1
# 8          50       RM         51.0     6120   Pave   NaN      Reg
# 9         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... MiscVal YrSold SaleType SaleCondition  \
# 0         Lvl    AllPub    Inside  ...       0   2008       WD        Normal
# 1         Lvl    AllPub       FR2  ...       0   2007       WD        Normal
# 2         Lvl    AllPub    Inside  ...       0   2008       WD        Normal
# 3         Lvl    AllPub    Corner  ...       0   2006       WD       Abnorml
# 4         Lvl    AllPub       FR2  ...       0   2008       WD        Normal
# 5         Lvl    AllPub    Inside  ...     700   2009       WD        Normal
# 6         Lvl    AllPub    Inside  ...       0   2007       WD        Normal
# 7         Lvl    AllPub    Corner  ...     350   2009       WD        Normal
# 8         Lvl    AllPub    Inside  ...       0   2008       WD       Abnorml
# 9         Lvl    AllPub    Corner  ...       0   2008       WD        Normal
#
#   SalePrice TotalSF  TotalPorchSF  TotalBath      SnMoSold      CsMoSold
# 0    208500    2566            61        3.5  8.660254e-01  5.000000e-01
# 1    181500    2524             0        2.5  5.000000e-01 -8.660254e-01
# 2    223500    2706            42        3.5 -1.000000e+00 -1.836970e-16
# 3    140000    2473           307        2.0  8.660254e-01  5.000000e-01
# 4    250000    3343            84        3.5 -2.449294e-16  1.000000e+00
# 5    143000    2158           350        2.5 -8.660254e-01  5.000000e-01
# 6    307000    3380            57        3.0 -8.660254e-01 -5.000000e-01
# 7    200000    3197           432        3.5 -5.000000e-01  8.660254e-01
# 8    129900    2726           205        2.0  8.660254e-01 -5.000000e-01
# 9    118000    2068             4        2.0  5.000000e-01  8.660254e-01
#
# [10 rows x 72 columns]

# %% [markdown]
# ![](https://image.flaticon.com/icons/png/128/3079/3079166.png)

# %%
df.HouseStyle.describe()
# Out:
# count       1455
# unique         8
# top       1Story
# freq         722
# Name: HouseStyle, dtype: object

# %%
df.HouseStyle.unique()
# Out:
# array(['2Story', '1Story', '1.5Fin', '1.5Unf', 'SFoyer', 'SLvl', '2.5Unf',
#        '2.5Fin'], dtype=object)

# %%
df['HouseStyle'].replace({'2Story':0, '1Story':1 ,  '1.5Fin':2, '1.5Unf':3})
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1455    0
# 1456    1
# 1457    0
# 1458    1
# 1459    1
# Name: HouseStyle, Length: 1455, dtype: object

# %%
df.columns.get_loc("HouseStyle")
# Out:
# 15

# %% [markdown]
# #### df.replace

# %%
df.insert(df.columns.get_loc("HouseStyle"),"HouseStyle_Enc" ,  df['HouseStyle'].replace({'2Story':0, '1Story':1 ,  '1.5Fin':2, '1.5Unf':3}))

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... MiscVal YrSold SaleType  \
# 0            Lvl    AllPub    Inside  ...       0   2008       WD
# 1            Lvl    AllPub       FR2  ...       0   2007       WD
# 2            Lvl    AllPub    Inside  ...       0   2008       WD
# 3            Lvl    AllPub    Corner  ...       0   2006       WD
# 4            Lvl    AllPub       FR2  ...       0   2008       WD
# ...          ...       ...       ...  ...     ...    ...      ...
# 1455         Lvl    AllPub    Inside  ...       0   2007       WD
# 1456         Lvl    AllPub    Inside  ...       0   2010       WD
# 1457         Lvl    AllPub    Inside  ...    2500   2010       WD
# 1458         Lvl    AllPub    Inside  ...       0   2010       WD
# 1459         Lvl    AllPub    Inside  ...       0   2008       WD
#
#      SaleCondition SalePrice TotalSF TotalPorchSF  TotalBath      SnMoSold  \
# 0           Normal    208500    2566           61        3.5  8.660254e-01
# 1           Normal    181500    2524            0        2.5  5.000000e-01
# 2           Normal    223500    2706           42        3.5 -1.000000e+00
# 3          Abnorml    140000    2473          307        2.0  8.660254e-01
# 4           Normal    250000    3343           84        3.5 -2.449294e-16
# ...            ...       ...     ...          ...        ...           ...
# 1455        Normal    175000    2600           40        2.5 -8.660254e-01
# 1456        Normal    210000    3615            0        3.0  8.660254e-01
# 1457        Normal    266500    3492           60        2.0  5.000000e-01
# 1458        Normal    142125    2156          112        2.0  8.660254e-01
# 1459        Normal    147500    2512           68        2.5  1.224647e-16
#
#           CsMoSold
# 0     5.000000e-01
# 1    -8.660254e-01
# 2    -1.836970e-16
# 3     5.000000e-01
# 4     1.000000e+00
# ...            ...
# 1455 -5.000000e-01
# 1456  5.000000e-01
# 1457 -8.660254e-01
# 1458 -5.000000e-01
# 1459 -1.000000e+00
#
# [1455 rows x 73 columns]

# %%
df.drop("HouseStyle_Enc", axis=1, inplace=True)

# %% [markdown]
# #### df.map

# %%
loc= df.columns.get_loc("HouseStyle")
enc= {'2Story':0, '1Story':1 ,  '1.5Fin':2, '1.5Unf':3}
df.insert(loc,"HouseStyle_Enc",  df.HouseStyle.map(enc))

# %%
df
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  TotalBath      SnMoSold      CsMoSold
# 0          60       RL         65.0  ...        3.5  8.660254e-01  5.000000e-01
# 1          20       RL         80.0  ...        2.5  5.000000e-01 -8.660254e-01
# 2          60       RL         68.0  ...        3.5 -1.000000e+00 -1.836970e-16
# 3          70       RL         60.0  ...        2.0  8.660254e-01  5.000000e-01
# 4          60       RL         84.0  ...        3.5 -2.449294e-16  1.000000e+00
# 5          50       RL         85.0  ...        2.5 -8.660254e-01  5.000000e-01
# 6          20       RL         75.0  ...        3.0 -8.660254e-01 -5.000000e-01
# 7          60       RL          NaN  ...        3.5 -5.000000e-01  8.660254e-01
# 8          50       RM         51.0  ...        2.0  8.660254e-01 -5.000000e-01
# 9         190       RL         50.0  ...        2.0  5.000000e-01  8.660254e-01
#
# [10 rows x 73 columns]

# %% [markdown]
# #### LabelEncoder

# %%
# Nan لابد من التاكد من خلو الخاصيو من قيم  غير مجهولة 
df.HouseStyle.isna().sum()
# في حالة تواجد قيم مجهولة  فلابد من معالجتها وذلك نم خلال استبدالها
# Out:
# 0

# %%
df[["HouseStyle", "HouseStyle_Enc"]].head(3)
# Out:
#   HouseStyle  HouseStyle_Enc
# 0     2Story               0
# 1     1Story               1
# 2     2Story               0

# %%
# labelEncoder       سيتم الاستغناء هنا عن ترميز البيانات يدويا
from sklearn.preprocessing import LabelEncoder
lblEnc=LabelEncoder()
df["HouseSyle_Enc"]=lblEnc.fit_transform(df.HouseStyle)
df[["HouseStyle", "HouseStyle_Enc"]].head(3)
# Out:
#   HouseStyle  HouseStyle_Enc
# 0     2Story               0
# 1     1Story               1
# 2     2Story               0

# %%
lblEnc.inverse_transform([0,1,2])
# Out:
# array(['1.5Fin', '1.5Unf', '1Story'], dtype=object)

# %%
# يمكن ترميز العديد  من الخصائص بنفس الطريقة 
# وبطبيعة الحال لاستغناء عن البيانات النصية ومعالجتها فيما بعد يخوارزمية ملائمة
df[["HouseStyle", "LotConfig"]].head(10)
# Out:
#   HouseStyle LotConfig
# 0     2Story    Inside
# 1     1Story       FR2
# 2     2Story    Inside
# 3     2Story    Corner
# 4     2Story       FR2
# 5     1.5Fin    Inside
# 6     1Story    Inside
# 7     2Story    Corner
# 8     1.5Fin    Inside
# 9     1.5Unf    Corner

# %%
for col in ["a", "b"] :
  print(col)
# Out:
# a
# b

# %%
for col in ["HouseStyle", "LotConfig"]:
  lblEnc=LabelEncoder()
  df[col]=lblEnc.fit_transform(df[col])

# %%
df[["HouseStyle", "LotConfig"]].head(10)
# Out:
#    HouseStyle  LotConfig
# 0           3          2
# 1           2          1
# 2           3          2
# 3           3          0
# 4           3          1
# 5           0          2
# 6           2          2
# 7           3          0
# 8           0          2
# 9           1          0
