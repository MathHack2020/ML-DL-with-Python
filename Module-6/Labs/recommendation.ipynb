# %%
import pandas as pd
import numpy as np
df= pd.Series(["ahmed", "samir", "Aicha", "faten"])
df
# Out:
# 0    ahmed
# 1    samir
# 2    Aicha
# 3    faten
# dtype: object

# %%
df.str.lower()
# Out:
# 0    ahmed
# 1    samir
# 2    aicha
# 3    faten
# dtype: object

# %%
df.shape
# Out:
# (4,)

# %%
df.str.len()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
df.str.contains(" ")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df[0]
# Out:
# 'ahmed'

# %%
print(df.str.cat(step=" "))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c54da339fc35> in <module>()
# ----> 1 print(df.str.cat(step=" "))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1999                 )
#    2000                 raise TypeError(msg)
# -> 2001             return func(self, *args, **kwargs)
#    2002
#    2003         wrapper.__name__ = func_name
#
# TypeError: cat() got an unexpected keyword argument 'step'
