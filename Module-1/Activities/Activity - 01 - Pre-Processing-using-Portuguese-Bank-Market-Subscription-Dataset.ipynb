# %% [markdown]
# - Dataset Overview
#
# The dataset contains 41,199 instances with 21 attributes. The attributes capture various demographic, financial, and contact-related information about individuals who were part of a telemarketing campaign. The goal is  to predict the target variable 'y', which is  a binary indicator of whether the client subscribed to the product (e.g., term deposit).
#
# - Attribute Descriptions
#
# + Demographic:
#      + age: Age of the client (numerical).
#      + job: Type of job (categorical).
#     + marital: Marital status (categorical).
#     + education: Education level (categorical).
# + Financial:
#     +  default: Has credit in default? (categorical).
#     +  housing: Has housing loan? (categorical).
#     +  loan: Has personal loan? (categorical).
# + Contact-Related:
#     + contact: Contact communication type (categorical).
#     + month: Last contact month of the year (categorical).
#     + day_of_week: Last contact day of the week (categorical).
#     + duration: Last contact duration in seconds (numerical).
#
# + Campaign-Related:
#     + campaign: Number of contacts performed during this campaign for this client (numerical).
#     + pdays: Number of days that passed by after the client was last contacted from a previous + campaign (numerical).
#     + previous: Number of contacts performed before this campaign for this client (numerical).
# + poutcome: Outcome of the previous marketing campaign (categorical).
#
# + Economic Indicators:
#     + emp_var_rate: Employment variation rate - quarterly indicator (numerical).
#     + cons_price_idx: Consumer price index - monthly indicator (numerical).
#     + cons_conf_idx: Consumer confidence index - monthly indicator (numerical).
#     + euribor3m: Euribor 3-month rate - daily indicator (numerical).
#     + nr_employed: Number of employees - quarterly indicator (numerical).
# + Target Variable:
#     + y: Has the client subscribed to a term deposit? (binary, 1 for yes, 0 for no).
#
# Potential Insights
#
# The dataset includes a mix of categorical and numerical features, requiring appropriate preprocessing steps for machine learning.
# The economic indicators might provide valuable context for understanding how macroeconomic factors influence subscription behavior.
# The contact-related and campaign-related features can help analyze the effectiveness of different outreach strategies.
# The demographic and financial features can be used to segment customers and identify potentially high-value targets.

# %% [markdown]
# ### 1.Dataset loading

# %%
pwd
# Out:
# '/workspaces/Data-Science-with-Python-master/Chapter01/Activities'

# %%
import pandas as pd    
import numpy as np
# Dataframe 
df = pd.read_csv("../data/house_price.csv", index_col=[0])

# %%
df.head()
# Out:
#     age          job  marital          education  default housing loan  \
# 0  44.0  blue-collar  married           basic.4y  unknown     yes   no
# 1  53.0   technician  married            unknown       no      no   no
# 2  28.0   management   single  university.degree       no     yes   no
# 3  39.0     services  married        high.school       no      no   no
# 4  55.0      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# 0          1.4          93.444          -36.1      4.963       5228.1  0
# 1         -0.1          93.200          -42.0      4.021       5195.8  0
# 2         -1.7          94.055          -39.8      0.729       4991.6  1
# 3         -1.8          93.075          -47.1      1.405       5099.1  0
# 4         -2.9          92.201          -31.4      0.869       5076.2  1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.	Feature Engineering !

# %%
# Dataframe Dimension 
df.shape
# Out:
# (41199, 21)

# %%
# datframe infroamtion 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41197 non-null  float64
#  1   job             41199 non-null  object
#  2   marital         41199 non-null  object
#  3   education       41199 non-null  object
#  4   default         41199 non-null  object
#  5   housing         41199 non-null  object
#  6   loan            41199 non-null  object
#  7   contact         41193 non-null  object
#  8   month           41199 non-null  object
#  9   day_of_week     41199 non-null  object
#  10  duration        41192 non-null  float64
#  11  campaign        41199 non-null  int64
#  12  pdays           41199 non-null  int64
#  13  previous        41199 non-null  int64
#  14  poutcome        41199 non-null  object
#  15  emp_var_rate    41199 non-null  float64
#  16  cons_price_idx  41199 non-null  float64
#  17  cons_conf_idx   41199 non-null  float64
#  18  euribor3m       41199 non-null  float64
#  19  nr_employed     41199 non-null  float64
#  20  y               41199 non-null  int64
# dtypes: float64(7), int64(4), object(10)
# memory usage: 6.9+ MB

# %%
# Statistics 
df.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41197.0    40.023812   10.434966     1.000    32.000
# duration        41192.0   258.274762  259.270089     0.000   102.000
# campaign        41199.0     2.567514    2.769719     1.000     1.000
# pdays           41199.0   962.485206  186.886905     0.000   999.000
# previous        41199.0     0.172941    0.494859     0.000     0.000
# emp_var_rate    41199.0     0.081900    1.570971    -3.400    -1.800
# cons_price_idx  41199.0    93.575650    0.578845    92.201    93.075
# cons_conf_idx   41199.0   -40.502002    4.628524   -50.800   -42.700
# euribor3m       41199.0     3.621336    1.734431     0.634     1.344
# nr_employed     41199.0  5167.036455   72.249592  4963.600  5099.100
# y               41199.0     0.112648    0.316166     0.000     0.000
#
#                      50%       75%       max
# age               38.000    47.000   104.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# pdays            999.000   999.000   999.000
# previous           0.000     0.000     7.000
# emp_var_rate       1.100     1.400     1.400
# cons_price_idx    93.749    93.994    94.767
# cons_conf_idx    -41.800   -36.400   -26.900
# euribor3m          4.857     4.961     5.045
# nr_employed     5191.000  5228.100  5228.100
# y                  0.000     0.000     1.000

# %% [markdown]
# ### 3.	Detect Missing Values

# %%
# missing values
df.isna()
# Out:
#          age    job  marital  education  default  housing   loan  contact  \
# 0      False  False    False      False    False    False  False    False
# 1      False  False    False      False    False    False  False    False
# 2      False  False    False      False    False    False  False    False
# 3      False  False    False      False    False    False  False    False
# 4      False  False    False      False    False    False  False    False
# ...      ...    ...      ...        ...      ...      ...    ...      ...
# 41194  False  False    False      False    False    False  False    False
# 41195  False  False    False      False    False    False  False     True
# 41196  False  False    False      False    False    False  False     True
# 41197   True  False    False      False    False    False  False    False
# 41198   True  False    False      False    False    False  False    False
#
#        month  day_of_week  ...  campaign  pdays  previous  poutcome  \
# 0      False        False  ...     False  False     False     False
# 1      False        False  ...     False  False     False     False
# 2      False        False  ...     False  False     False     False
# 3      False        False  ...     False  False     False     False
# 4      False        False  ...     False  False     False     False
# ...      ...          ...  ...       ...    ...       ...       ...
# 41194  False        False  ...     False  False     False     False
# 41195  False        False  ...     False  False     False     False
# 41196  False        False  ...     False  False     False     False
# 41197  False        False  ...     False  False     False     False
# 41198  False        False  ...     False  False     False     False
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 0             False           False          False      False        False
# 1             False           False          False      False        False
# 2             False           False          False      False        False
# 3             False           False          False      False        False
# 4             False           False          False      False        False
# ...             ...             ...            ...        ...          ...
# 41194         False           False          False      False        False
# 41195         False           False          False      False        False
# 41196         False           False          False      False        False
# 41197         False           False          False      False        False
# 41198         False           False          False      False        False
#
#            y
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 41194  False
# 41195  False
# 41196  False
# 41197  False
# 41198  False
#
# [41199 rows x 21 columns]

# %%
# count missing values
df.isna().sum()
# Out:
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
# display rows having missing values 
df[df.isna().any(axis=1)]
# Out:
#          age         job  marital            education  default housing loan  \
# 41185   42.0      admin.   single    university.degree  unknown     yes  yes
# 41186   48.0  technician  married  professional.course       no      no  yes
# 41188   25.0     student   single          high.school       no      no   no
# 41189  103.0  technician  married          high.school       no      no    n
# 41190   29.0  technician   single                Basic       no     yes    n
# 41191   44.0    services  married          high.school  unknown     yes    y
# 41192   39.0      admin.  married    university.degree       no      no    y
# 41193    1.0      admin.  married          high.school       no     yes    y
# 41195    2.0   housemaid  married                Basic  unknown      no    n
# 41196    3.0      admin.   single    university.degree  unknown     yes    y
# 41197    NaN  technician  married  professional.course       no      no    n
# 41198    NaN     student   single          high.school       no      no    n
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 41185  telephone   may         wed  ...         3    999         0
# 41186  telephone   oct         tue  ...         2    999         0
# 41188        NaN   may         fri  ...         4    999         0
# 41189        NaN   aug         fri  ...         1    999         0
# 41190        NaN   may         mon  ...         1    999         0
# 41191        NaN   aug         fri  ...         1    999         0
# 41192   cellular   nov         tue  ...         2    999         0
# 41193   cellular   may         thu  ...         4    999         1
# 41195        NaN   may         thu  ...         2    999         0
# 41196        NaN   may         wed  ...         3    999         0
# 41197  telephone   oct         tue  ...         2    999         0
# 41198  telephone   may         fri  ...         4    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 41185  nonexistent          1.1          93.994          -36.4      4.857
# 41186  nonexistent         -3.4          92.431          -26.9      0.742
# 41188  nonexistent          1.1          93.994          -36.4      4.859
# 41189  nonexistent          1.4          93.444          -36.1      4.966
# 41190  nonexistent         -1.8          92.893          -46.2      1.299
# 41191  nonexistent          1.4          93.444          -36.1      4.966
# 41192  nonexistent         -0.1          93.200          -42.0      4.153
# 41193      failure         -1.8          92.893          -46.2      1.266
# 41195  nonexistent          1.1          93.994          -36.4      4.860
# 41196  nonexistent          1.1          93.994          -36.4      4.857
# 41197  nonexistent         -3.4          92.431          -26.9      0.742
# 41198  nonexistent          1.1          93.994          -36.4      4.859
#
#        nr_employed  y
# 41185       5191.0  0
# 41186       5017.5  0
# 41188       5191.0  0
# 41189       5228.1  1
# 41190       5099.1  0
# 41191       5228.1  0
# 41192       5195.8  0
# 41193       5099.1  0
# 41195       5191.0  0
# 41196       5191.0  0
# 41197       5017.5  0
# 41198       5191.0  0
#
# [12 rows x 21 columns]

# %%
# features having missing values 
df.isna().sum()
# Out:
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
# %  MIssing values by  feature 
(df.isna().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# duration          0.000170
# contact           0.000146
# age               0.000049
# job               0.000000
# marital           0.000000
# default           0.000000
# education         0.000000
# loan              0.000000
# housing           0.000000
# month             0.000000
# day_of_week       0.000000
# campaign          0.000000
# pdays             0.000000
# previous          0.000000
# poutcome          0.000000
# emp_var_rate      0.000000
# cons_price_idx    0.000000
# cons_conf_idx     0.000000
# euribor3m         0.000000
# nr_employed       0.000000
# y                 0.000000
# dtype: float64

# %%
#finding the data types of each column and checking for null
# null_ = df.isna().any()
# dtypes = df.dtypes
# sum_na_ = df.isna().sum()
# info = pd.concat([null_,sum_na_,dtypes],axis = 1,keys = ['isNullExist','NullSum','type'])
# info
# Out:
#                 isNullExist  NullSum     type
# age                    True        2  float64
# job                   False        0   object
# marital               False        0   object
# education             False        0   object
# default               False        0   object
# housing               False        0   object
# loan                  False        0   object
# contact                True        6   object
# month                 False        0   object
# day_of_week           False        0   object
# duration               True        7  float64
# campaign              False        0    int64
# pdays                 False        0    int64
# previous              False        0    int64
# poutcome              False        0   object
# emp_var_rate          False        0  float64
# cons_price_idx        False        0  float64
# cons_conf_idx         False        0  float64
# euribor3m             False        0  float64
# nr_employed           False        0  float64
# y                     False        0    int64

# %% [markdown]
# ### 4.	Drop NULL  Values

# %%
# Drop rows ahving null values
df = df.dropna()

# %%
# check missing values 
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ### 5.	features Values count

# %%
df.marital.unique()
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
for col in df.select_dtypes(include="object") :
    print(f" Categories. {col}:  {df[col].unique()}")
# Out:
#  Categories. job:  ['blue-collar' 'technician' 'management' 'services' 'retired' 'admin.'
#  'housemaid' 'unemployed' 'entrepreneur' 'self-employed' 'unknown'
#  'student']
#  Categories. marital:  ['married' 'single' 'divorced' 'unknown']
#  Categories. education:  ['basic.4y' 'unknown' 'university.degree' 'high.school' 'basic.9y'
#  'professional.course' 'basic.6y' 'illiterate']
#  Categories. default:  ['unknown' 'no' 'yes']
#  Categories. housing:  ['yes' 'no' 'unknown']
#  Categories. loan:  ['no' 'yes' 'unknown']
#  Categories. contact:  ['cellular' 'telephone']
#  Categories. month:  ['aug' 'nov' 'jun' 'apr' 'jul' 'may' 'oct' 'mar' 'sep' 'dec']
#  Categories. day_of_week:  ['thu' 'fri' 'tue' 'mon' 'wed']
#  Categories. poutcome:  ['nonexistent' 'success' 'failure']

# %%
df.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
df.education.value_counts()
# Out:
# education
# university.degree      12167
# high.school             9516
# basic.9y                6045
# professional.course     5242
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %% [markdown]
# ### 6.	Encode  a Categotrical Feature

# %%
df.housing.unique()
# Out:
# array(['yes', 'no', 'unknown'], dtype=object)

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['housing_encoded'] = encoder.fit_transform(df['housing'])

# %%
# Encoding schema 
encoder.classes_, f" encoed to  {df.housing_encoded.unique()}"
# Out:
# (array(['no', 'unknown', 'yes'], dtype=object), ' encoed to  [2 0 1]')

# %%
for index, value in enumerate(encoder.classes_):
    print(f"Index {index}: {value}")
# Out:
# Index 0: no
# Index 1: unknown
# Index 2: yes

# %%
# display both encoded and non encode features 
df[["housing", "housing_encoded"]].sample(10)
# Out:
#       housing  housing_encoded
# 29674     yes                2
# 37354     yes                2
# 32025     yes                2
# 32003     yes                2
# 24264      no                0
# 28718     yes                2
# 9244       no                0
# 6254      yes                2
# 38249     yes                2
# 6281      yes                2

# %%
df[df.housing_encoded==1][["housing", "housing_encoded"]]
# Out:
#        housing  housing_encoded
# 90     unknown                1
# 101    unknown                1
# 102    unknown                1
# 157    unknown                1
# 160    unknown                1
# ...        ...              ...
# 41004  unknown                1
# 41102  unknown                1
# 41122  unknown                1
# 41132  unknown                1
# 41158  unknown                1
#
# [990 rows x 2 columns]

# %% [markdown]
# ### 7.	Encode All Categorical dataframe features

# %%
# drop that housing_encoed features just create 
df.drop(["housing_encoded"], axis=1, inplace=True)

# %%
df.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
# Categorcial features 
categorical_features  = df.select_dtypes(exclude="number").columns

# Numerical features 
numerical_features = df.select_dtypes(include="object").columns

# %%
categorical_features
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
numerical_features
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
df_oneHotEncoding= pd.get_dummies(df[categorical_features])

# %%
df_oneHotEncoding.head()
# Out:
#    job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 0       False             True             False          False
# 1       False            False             False          False
# 2       False            False             False          False
# 3       False            False             False          False
# 4       False            False             False          False
#
#    job_management  job_retired  job_self-employed  job_services  job_student  \
# 0           False        False              False         False        False
# 1           False        False              False         False        False
# 2            True        False              False         False        False
# 3           False        False              False          True        False
# 4           False         True              False         False        False
#
#    job_technician  ...  month_oct  month_sep  day_of_week_fri  \
# 0           False  ...      False      False            False
# 1            True  ...      False      False             True
# 2           False  ...      False      False            False
# 3           False  ...      False      False             True
# 4           False  ...      False      False             True
#
#    day_of_week_mon  day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# 0            False             True            False            False
# 1            False            False            False            False
# 2            False             True            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    poutcome_failure  poutcome_nonexistent  poutcome_success
# 0             False                  True             False
# 1             False                  True             False
# 2             False                 False              True
# 3             False                  True             False
# 4             False                 False              True
#
# [5 rows x 53 columns]

# %%
df_result = pd.concat([df[numerical_features
                          ],df_oneHotEncoding],axis=1)

# %%
df_result.head()
# Out:
#            job  marital          education  default housing loan   contact  \
# 0  blue-collar  married           basic.4y  unknown     yes   no  cellular
# 1   technician  married            unknown       no      no   no  cellular
# 2   management   single  university.degree       no     yes   no  cellular
# 3     services  married        high.school       no      no   no  cellular
# 4      retired  married           basic.4y       no     yes   no  cellular
#
#   month day_of_week     poutcome  ...  month_oct  month_sep  day_of_week_fri  \
# 0   aug         thu  nonexistent  ...      False      False            False
# 1   nov         fri  nonexistent  ...      False      False             True
# 2   jun         thu      success  ...      False      False            False
# 3   apr         fri  nonexistent  ...      False      False             True
# 4   aug         fri      success  ...      False      False             True
#
#    day_of_week_mon  day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# 0            False             True            False            False
# 1            False            False            False            False
# 2            False             True            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    poutcome_failure  poutcome_nonexistent  poutcome_success
# 0             False                  True             False
# 1             False                  True             False
# 2             False                 False              True
# 3             False                  True             False
# 4             False                 False              True
#
# [5 rows x 63 columns]

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41187 entries, 0 to 41194
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   job                            41187 non-null  object
#  1   marital                        41187 non-null  object
#  2   education                      41187 non-null  object
#  3   default                        41187 non-null  object
#  4   housing                        41187 non-null  object
#  5   loan                           41187 non-null  object
#  6   contact                        41187 non-null  object
#  7   month                          41187 non-null  object
#  8   day_of_week                    41187 non-null  object
#  9   poutcome                       41187 non-null  object
#  10  job_admin.                     41187 non-null  bool
#  11  job_blue-collar                41187 non-null  bool
#  12  job_entrepreneur               41187 non-null  bool
#  13  job_housemaid                  41187 non-null  bool
#  14  job_management                 41187 non-null  bool
#  15  job_retired                    41187 non-null  bool
#  16  job_self-employed              41187 non-null  bool
#  17  job_services                   41187 non-null  bool
#  18  job_student                    41187 non-null  bool
#  19  job_technician                 41187 non-null  bool
#  20  job_unemployed                 41187 non-null  bool
#  21  job_unknown                    41187 non-null  bool
#  22  marital_divorced               41187 non-null  bool
#  23  marital_married                41187 non-null  bool
#  24  marital_single                 41187 non-null  bool
#  25  marital_unknown                41187 non-null  bool
#  26  education_basic.4y             41187 non-null  bool
#  27  education_basic.6y             41187 non-null  bool
#  28  education_basic.9y             41187 non-null  bool
#  29  education_high.school          41187 non-null  bool
#  30  education_illiterate           41187 non-null  bool
#  31  education_professional.course  41187 non-null  bool
#  32  education_university.degree    41187 non-null  bool
#  33  education_unknown              41187 non-null  bool
#  34  default_no                     41187 non-null  bool
#  35  default_unknown                41187 non-null  bool
#  36  default_yes                    41187 non-null  bool
#  37  housing_no                     41187 non-null  bool
#  38  housing_unknown                41187 non-null  bool
#  39  housing_yes                    41187 non-null  bool
#  40  loan_no                        41187 non-null  bool
#  41  loan_unknown                   41187 non-null  bool
#  42  loan_yes                       41187 non-null  bool
#  43  contact_cellular               41187 non-null  bool
#  44  contact_telephone              41187 non-null  bool
#  45  month_apr                      41187 non-null  bool
#  46  month_aug                      41187 non-null  bool
#  47  month_dec                      41187 non-null  bool
#  48  month_jul                      41187 non-null  bool
#  49  month_jun                      41187 non-null  bool
#  50  month_mar                      41187 non-null  bool
#  51  month_may                      41187 non-null  bool
#  52  month_nov                      41187 non-null  bool
#  53  month_oct                      41187 non-null  bool
#  54  month_sep                      41187 non-null  bool
#  55  day_of_week_fri                41187 non-null  bool
#  56  day_of_week_mon                41187 non-null  bool
#  57  day_of_week_thu                41187 non-null  bool
#  58  day_of_week_tue                41187 non-null  bool
#  59  day_of_week_wed                41187 non-null  bool
#  60  poutcome_failure               41187 non-null  bool
#  61  poutcome_nonexistent           41187 non-null  bool
#  62  poutcome_success               41187 non-null  bool
# dtypes: bool(53), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# ### 8.	Dataframe Split into Training & test datasets

# %%
df.head()
# Out:
#     age          job  marital          education  default housing loan  \
# 0  44.0  blue-collar  married           basic.4y  unknown     yes   no
# 1  53.0   technician  married            unknown       no      no   no
# 2  28.0   management   single  university.degree       no     yes   no
# 3  39.0     services  married        high.school       no      no   no
# 4  55.0      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# 0          1.4          93.444          -36.1      4.963       5228.1  0
# 1         -0.1          93.200          -42.0      4.021       5195.8  0
# 2         -1.7          94.055          -39.8      0.729       4991.6  1
# 3         -1.8          93.075          -47.1      1.405       5099.1  0
# 4         -2.9          92.201          -31.4      0.869       5076.2  1
#
# [5 rows x 21 columns]

# %%
df.iloc[:,-1]
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 41182    0
# 41183    0
# 41184    0
# 41187    0
# 41194    0
# Name: y, Length: 41187, dtype: int64

# %%
# Get independant varaibles  and target  feature
X=df_result.iloc[:,:-1]
y=df_result.iloc[:,-1]

# %%
# Split data ito training and test sets 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3)

# %%
print("FULL Dateset X Shape: ", X.shape )
print("Train Dateset X Shape: ", X_train.shape )
print("Train Dateset y Shape: ", y_train.shape )
print("Test Dateset X Shape: ", X_test.shape )
print("Test Dateset y Shape: ", y_test.shape )
# Out:
# FULL Dateset X Shape:  (41187, 62)
# Train Dateset X Shape:  (28830, 62)
# Train Dateset y Shape:  (28830,)
# Test Dateset X Shape:  (12357, 62)
# Test Dateset y Shape:  (12357,)
