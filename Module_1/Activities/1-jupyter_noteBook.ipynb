# %% [markdown]
# ### Jupyter Fundamentals

# %%
# Get the numpy arange docstring
import numpy as np
np.arange ?
# Out:
#   Cell In[4], line 3
#     np.arange ?
#               ^
# SyntaxError: invalid syntax

# %%
# Get the python sort function docstring
sorted?
# Out:
# Signature: sorted(iterable, /, *, key=None, reverse=False)
# Docstring:
# Return a new list containing all items from the iterable in ascending order.
#
# A custom key function can be supplied to customize the sort order, and the
# reverse flag can be set to request the result in descending order.
# Type:      builtin_function_or_method

# %%
# Display plots inline
# %matplotlib inline

# %%
a = [1, 2, 3] * 5
a
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# %%time
# Get runtime for the entire cell

for i in range(len(a)):
    a[i] += 5
# Out:
# CPU times: user 7 μs, sys: 0 ns, total: 7 μs
# Wall time: 10 μs

# %%
# Average results of many runs
# %timeit set(a)
# Out:
# 293 ns ± 25.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%bash
#
# echo " Bash command within Jupyter !" > test-file.txt
# ls
# echo ""
# cat test-file.txt
# rm test-file.txt
# Out:
# Activity - 01 - Pre-Processing-using-Portuguese-Bank-Market-Subscription-Dataset.ipynb
# jupyter_noteBook.ipynb
# test-file.txt
#
#  Bash command within Jupyter !

# %%
ls
# Out:
# 'Activity - 01 - Pre-Processing-using-Portuguese-Bank-Market-Subscription-Dataset.ipynb'
#  jupyter_noteBook.ipynb

# %%
pwd
# Out:
# '/workspaces/Data-Science-with-Python-master/Chapter01/Activities'

# %%
from sklearn.datasets import fetch_openml
import pandas as pd
housing = fetch_openml(name="house_prices", as_frame=True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
housing.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
housing.feature_names
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
df.Neighborhood
# Out:
# 0       CollgCr
# 1       Veenker
# 2       CollgCr
# 3       Crawfor
# 4       NoRidge
#          ...
# 1455    Gilbert
# 1456     NWAmes
# 1457    Crawfor
# 1458      NAmes
# 1459    Edwards
# Name: Neighborhood, Length: 1460, dtype: object

# %%
from IPython.display import display, HTML
display(HTML(f"<pre>{housing.DESCR}</pre>"))
# Out:
# <pre>Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
# ...

# %%
print(housing.target)
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# build dataframe out of the housing vairable 
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.shape[1]
# Out:
# 81

# %%
df.LotFrontage.sample(3)
# Out:
# 1151    134.0
# 1413     88.0
# 1451     78.0
# Name: LotFrontage, dtype: float64

# %%
# Move the target variable to the front of the table

df = pd.concat((df, housing.target), axis=1)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df[['MSZoning', 'Street', 'Alley', 'LotShape']].tail()
# Out:
#      MSZoning Street Alley LotShape
# 1455       RL   Pave   NaN      Reg
# 1456       RL   Pave   NaN      Reg
# 1457       RL   Pave   NaN      Reg
# 1458       RL   Pave   NaN      Reg
# 1459       RL   Pave   NaN      Reg

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# Identify and NaNs
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Removing some columns
for col in ['LotFrontage', 'HeatingQC', 'CentralAir']:
    del df[col]

# %%
df.keys()
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# ...

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
cols=df.select_dtypes(include="number").columns
df[cols].corr()
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.011156 -0.033226    -0.028365     0.012609
# MSSubClass     0.011156    1.000000 -0.139781     0.032628    -0.059316
# LotArea       -0.033226   -0.139781  1.000000     0.105806    -0.005636
# OverallQual   -0.028365    0.032628  0.105806     1.000000    -0.091932
# OverallCond    0.012609   -0.059316 -0.005636    -0.091932     1.000000
# YearBuilt     -0.012713    0.027850  0.014228     0.572323    -0.375983
# YearRemodAdd  -0.021998    0.040581  0.013788     0.550684     0.073741
# MasVnrArea    -0.050298    0.022936  0.104160     0.411876    -0.128101
# BsmtFinSF1    -0.005024   -0.069836  0.214103     0.239666    -0.046231
# BsmtFinSF2    -0.005968   -0.065649  0.111170    -0.059119     0.040229
# BsmtUnfSF     -0.007940   -0.140759 -0.002618     0.308159    -0.136841
# TotalBsmtSF   -0.015415   -0.238518  0.260833     0.537808    -0.171098
# ...

# %%
# The pairwise correlations
cols= ['BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF']
df[cols].corr()
# Out:
#              BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF
# BsmtUnfSF     1.000000     0.415360  0.317987  0.004469
# TotalBsmtSF   0.415360     1.000000  0.819530 -0.174512
# 1stFlrSF      0.317987     0.819530  1.000000 -0.202646
# 2ndFlrSF      0.004469    -0.174512 -0.202646  1.000000

# %%
# Visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Pairwise correlation heatmap
ax = sns.heatmap(df[cols].corr(),
                 cmap=sns.cubehelix_palette(20, light=0.95, dark=0.15))
ax.xaxis.tick_top() # move labels to the top

plt.savefig('../imgs/graph1.png',
            bbox_inches='tight', dpi=300)

# %%
sns.pairplot(df[cols],
             plot_kws={'alpha': 0.6},
             diag_kws={'bins': 30})

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))  # Adjust figsize as needed

sns.regplot(x='BsmtUnfSF', y='SalePrice', data=df, ax=ax[0], scatter_kws={'alpha': 0.4})
sns.regplot(x='2ndFlrSF', y='SalePrice', data=df, ax=ax[1], scatter_kws={'alpha': 0.4})

plt.tight_layout(pad=3.0, w_pad=3.0)  # Adjust pad and w_pad as needed
plt.savefig('../imgs/graph_housing-scatter.png',
            bbox_inches='tight', dpi=300)

# %%
# Residual Plots
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.regplot(x='BsmtUnfSF', y='SalePrice', data=df, ax=ax[0], scatter_kws={'alpha': 0.4})
sns.residplot(x='BsmtUnfSF', y='SalePrice', data=df, ax=ax[0]) # Residual plot for BsmtUnfSF

sns.regplot(x='2ndFlrSF', y='SalePrice', data=df, ax=ax[1], scatter_kws={'alpha': 0.4})
sns.residplot(x='2ndFlrSF', y='SalePrice', data=df, ax=ax[1])  # Residual plot for 2ndFlrSF
# Out:
# <Axes: xlabel='2ndFlrSF', ylabel='SalePrice'>

# %%
# MSE of linear models

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def get_mse(df, feature, target="SalePrice"):
    # Get x, y to model
    y = df[target].values
    x = df[feature].values.reshape(-1,1)
    print('{} ~ {}'.format(target, feature))
    
    # Build and fit the model
    lm = LinearRegression()
    lm.fit(x, y)
    msg = 'model: y = {:.3f} + {:.3f}x'\
            .format(lm.intercept_, lm.coef_[0])
    print(msg)
    
    # Predict and determine MSE
    y_pred = lm.predict(x)
    error = mean_squared_error(y, y_pred)
    print('mse = {:.2f}'.format(error))
    print()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
df.select_dtypes(include="number").sample(10)
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1274  1275          50     5362            5            6       1910
# 252    253          60     8366            6            5       2004
# 613    614          20     8402            5            5       2007
# 204    205          50     3500            5            7       1947
# 941    942          60     8755            7            5       1999
# 1003  1004          90    11500            5            6       1976
# 265    266          20    12090            6            6       1981
# 207    208          20    12493            4            5       1960
# 583    584          75    13500           10            9       1893
# 1405  1406         120     3842            8            5       2004
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 1274          2003         0.0           0           0  ...         242
# ...

# %%
get_mse( df, 'LotArea')
# Out:
# SalePrice ~ LotArea
# model: y = 158836.152 + 2.100x
# mse = 5867752122.51
